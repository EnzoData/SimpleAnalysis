# %% [markdown]
# EDA for current job postings available on the City of New York’s official jobs site
# : https://www.kaggle.com/jolasa/quick-simple-analysis

# %% [markdown]
# Import the proper notebooks

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %% [markdown]
# Getting the Data and Shape

# %%
df = pd.read_csv("../input/nyc-jobs.csv")
df.shape
# Out:
# (3096, 28)

# %% [markdown]
# Looking to see if we we have missing values

# %%
df.count().sort_values()
# Out:
# Recruitment Contact                 0
# Post Until                        864
# Hours/Shift                       956
# Work Location 1                  1363
# Additional Information           1933
# Preferred Skills                 2712
# Full-Time/Part-Time indicator    2843
# Minimum Qual Requirements        3084
# Job Category                     3094
# To Apply                         3095
# Job ID                           3096
# Posting Date                     3096
# Residency Requirement            3096
# Job Description                  3096
# Work Location                    3096
# Posting Updated                  3096
# Salary Frequency                 3096
# Salary Range To                  3096
# Salary Range From                3096
# Level                            3096
# Title Code No                    3096
# Civil Service Title              3096
# Business Title                   3096
# # Of Positions                   3096
# Posting Type                     3096
# ...

# %% [markdown]
# 'Recruitment contact' is empty and 'Post Until' is not useful for the EDA. We can drop them

# %%
df.drop(['Recruitment Contact', 'Post Until'], axis=1, inplace=True)

# %% [markdown]
# Let's check some of the most important categorical features

# %%
sns.countplot(x = "Full-Time/Part-Time indicator", data = df, palette = "Set3")

# %%
sns.countplot(x = "Salary Frequency" , data = df, palette = "Set3")

# %%
sns.countplot(x = "Level" , data = df, order = df['Level'].value_counts().index, palette = "Set3")

# %%
plt.figure(figsize=(10,10))
plot = sns.countplot(y = "Job Category", data = df, order = df['Job Category'].value_counts().iloc[:10].index, palette = "Set3")

# %% [markdown]
# Some variables's distribution

# %%
sns.distplot(df['Salary Range From'], 
             kde_kws={"color": "coral", "lw": 1, "label": "KDE"}, 
             hist_kws={"histtype": "stepfilled", "linewidth": 1, "alpha": 1, "color": "skyblue"});

# %%
sns.distplot(df['Salary Range To'], 
             kde_kws={"color": "coral", "lw": 1, "label": "KDE"}, 
             hist_kws={"histtype": "stepfilled", "linewidth": 1, "alpha": 1, "color": "skyblue"});

# %%
sns.distplot(df['# Of Positions'], 
             kde_kws={"color": "coral", "lw": 1, "label": "KDE"}, 
             hist_kws={"histtype": "stepfilled", "linewidth": 1, "alpha": 1, "color": "skyblue"});

# %% [markdown]
# #Bussiest places

# %%
plt.figure(figsize=(11,11))
plot = sns.countplot(y = "Work Location", data = df, order = df['Work Location'].value_counts().iloc[:10].index, palette = "Set3")
